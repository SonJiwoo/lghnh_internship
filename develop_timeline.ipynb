# %%
import json
from collections import OrderedDict


def make_event(year, month, day, image_url, headline, text, credit=None, caption=None):
    global events
    year, month, day = str(year), str(month), str(day)
    tmp = OrderedDict()
    tmp['start_date'] = {'year':year, 'month':month, 'day':day}
    tmp['media'] = {'url':image_url,
                    'credit':credit if credit else '',
                    'caption':caption if caption else ''}
    tmp['text'] = {'headline':headline,
                   'text':text}
    events += [dict(tmp)]


events = list()
make_event(2023, 9, 6,
           image_url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/LG_Household_%26_Health_Care_logo_%28korean%29.svg/1280px-LG_Household_%26_Health_Care_logo_%28korean%29.svg.png',
           credit='LG Health & Beautiful',
           headline='INTERNSHIP', text='Data & Machine Learning Project')
make_event(2023, 9, 7,
           image_url = 'https://img1.tmon.kr/cdn4/deals/2023/10/12/4422196426/4422196426_mobile_9heGNg5vGS.jpg',
           headline = '[Project] 유사제품 군집화', text='수요예측을 위한 유사제품 군집화')
make_event(2023, 9, 8,
           image_url = 'https://miro.medium.com/v2/resize:fit:410/0*WufniiwEUNmciR-M.png',
           credit='Material Master Data',
           headline = '자재마스터 EDA', text='Hair Care / Oral Care / Cleanser / Softener')
make_event(2023, 9, 11,
           image_url = 'https://www.campussafetymagazine.com/wp-content/uploads/2021/10/unification-1000x500.jpg',
           credit = 'Product Name Preprocessing',
           headline = '자재명 전처리', text='자재명 형식 통일 (브랜드 + 브랜드라인 + 제품종류 + 제품상세)')
make_event(2023, 9, 18,
           image_url = 'https://blog.kakaocdn.net/dn/9ZoV8/btqA5QhV0LG/0gISSumuUCj9wlhRaWlmPk/img.png',
           credit = 'DBSCAN',
           headline = 'Clustering (1) DBSCAN 군집 배정', text='전처리된 자재명을 기준으로 DBSCAN 수행 <br> - TF-IDF + Count Vectorizer 활용 <br> - Robust한 군집 형성')
make_event(2023, 9, 20,
           image_url = 'https://blog.kakaocdn.net/dn/KZgqj/btqZSvOG1Sx/DnNYcc9FSYKD9cYIK2RW21/img.png',
           credit = 'SKU',
           headline = 'Clustering (2) 바코드 군집 통합', text='Clustering by BAR CODE <br> - 바코드를 공유하는 SKU가 서로 다른 군집에 존재하는 경우 통합 <br> - 제품그룹별 15~20% 내외 군집화 실패')
make_event(2023, 9, 23,
           image_url = 'https://miro.medium.com/v2/resize:fit:1400/1*IhpY-6LYV75983THCpWo-w.png',
           credit = 'Cosine Similarity',
           headline = 'Clustering (3) 실패 군집 재배정', text='바코드를 타겟으로, 자재명을 입력데이터로 BERT Model 학습 후 코사인 유사도 비교 <br> - Case1. 같은 바코드 2개 이상 시, 코사인 유사도 0.9인 군집에 배정 또는 별도 군집 형성 <br> - Case 2. 같은 바코드 없을 시, 코사인 유사도 0.9 이상인 군집에 배정 <br> - 제품그룹별 10% 내외 군집화 실패')
make_event(2023, 9, 25,
           image_url = 'https://global-uploads.webflow.com/6434d6a6071644318551fd72/6461ccca2a57c4ce037bbd7a_A644a6b53e8e906a4e3ea2d28.webp',
           credit = 'NER',
           headline = '군집별 상세 정보 추출', text='NER(개체명 인식)을 활용한 군집별 상세 정보 태깅 <br> - Model: spaCy <br> - spaCy의 한국어 NER 모델(ko-core-news-sm) 파인 튜닝 진행 <br> - 직접 훈련데이터 생성')
make_event(2023, 10, 1,
           image_url = 'https://letstranzact.com/_ipx/f_webp/semi_finished_goods.png',
           credit = 'Semi-Finished Product',
           headline = '반제품 데이터 확인', text='반제품 데이터 활용하여 같은 성분을 공유하는 자재 파악 가능')
make_event(2023, 10, 4,
           image_url = 'https://images.datacamp.com/image/upload/v1640050215/image27_frqkzv.png',
           credit = 'Streamlit',
           headline = '대시보드 구현', text='Dashboard Visualization')
make_event(2023, 10, 11,
           image_url = 'https://www.inria.fr/sites/default/files/2020-04/A_Optimisation_AdobeStock_142192811-1826x1027.jpeg',
           credit = 'Optimization & Upgrade',
           headline = '대시보드 최적화 및 고도화', text='NER 태그 기반 Dynamic Filters 적용 <br> - 4대 주요 제품그룹별 요약 <br> - 군집 미배정 자재 확인 및 수정 / 군집명 통합 및 수정 <br> - 매출 추이, 매출 비중, 데이터 확인, SKU 확인, 반제품 확인 <br> - 캐시데이터 활용을 통한 속도 개선')
make_event(2023, 10, 18,
           image_url = 'https://velog.velcdn.com/images/yeseong31/post/210024e5-b219-4d32-9cd7-31f6218158f1/image.png',
           credit = 'Clean Code',
           headline = '코드 정리', text='전체 과정 함수화 및 주석 달기')
make_event(2023, 10, 25,
           image_url = 'https://1622179098.rsc.cdn77.org/data/images/full/139281/sole-proprietorship-business-automatization-tools.jpeg',
           credit = 'Automization',
           headline = '자재마스터 전처리 자동화 페이지 제작', text='1. 자재마스터 전처리, 군집화 및 NER 태깅 자동화 <br> 2. 셀아웃 데이터와의 병합까지 자동화 일괄 처리')
make_event(2023, 10, 30,
           image_url = 'https://resources.careersandenterprise.co.uk/sites/default/files/2020-07/Group%201774.svg',
           credit = 'Guideline',
           headline = '대시보드 및 자동화 페이지 사용 가이드 제작', text='1. 자재마스터 전처리 자동화 <br> 2. 프론트 대시보드')


df = dict()
df['events'] = events


with open('develop_timeline.json', 'w') as f:
    json.dump(df, f)
